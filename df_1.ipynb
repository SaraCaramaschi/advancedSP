# %%
# Import tutto quanto
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import copy

# %%
#For non normal (all in this case) -> Wilcoxon-Mann-Whitney test
#Hp0: are they the same?

print('BUN\n', sci.mannwhitneyu(numerical_df['BUN_first'], numerical_df['BUN_last'], nan_policy='omit'))
#same
print('\n\nCreatinine\n', sci.mannwhitneyu(numerical_df['Creatinine_first'], numerical_df['Creatinine_last'], nan_policy='omit'))
#same
print('\n\nDiasABP\n', sci.mannwhitneyu(numerical_df['DiasABP_first'], numerical_df['DiasABP_last'], nan_policy='omit'))
#different
print('\n\nFiO2\n', sci.mannwhitneyu(numerical_df['FiO2_first'], numerical_df['FiO2_last'], nan_policy='omit'))
#different
print('\n\nGCS\n', sci.mannwhitneyu(numerical_df['GCS_first'], numerical_df['GCS_last'], nan_policy='omit'))
#different
print('\n\nGlucose\n', sci.mannwhitneyu(numerical_df['Glucose_first'], numerical_df['Glucose_last'], nan_policy='omit'))
#different
print('\n\nHCO3\n', sci.mannwhitneyu(numerical_df['HCO3_first'], numerical_df['HCO3_last'], nan_policy='omit'))
#different
print('\n\nHCT\n', sci.mannwhitneyu(numerical_df['HCT_first'], numerical_df['HCT_last'], nan_policy='omit'))
#different
print('\n\nHR\n', sci.mannwhitneyu(numerical_df['HR_first'], numerical_df['HR_last'], nan_policy='omit'))
#different
print('\n\nK\n', sci.mannwhitneyu(numerical_df['K_first'], numerical_df['K_last'], nan_policy='omit'))
#different
print('\n\nLactate\n', sci.mannwhitneyu(numerical_df['Lactate_first'], numerical_df['Lactate_last'], nan_policy='omit'))
#different
print('\n\nMAP\n', sci.mannwhitneyu(numerical_df['MAP_first'], numerical_df['MAP_last'], nan_policy='omit'))
#different
print('\n\nMg\n', sci.mannwhitneyu(numerical_df['Mg_first'], numerical_df['Mg_last'], nan_policy='omit'))
#different
print('\n\nNIDiasABP\n', sci.mannwhitneyu(numerical_df['NIDiasABP_first'], numerical_df['NIDiasABP_last'], nan_policy='omit'))
#different
print('\n\nNIMAP\n', sci.mannwhitneyu(numerical_df['NIMAP_first'], numerical_df['NIMAP_last'], nan_policy='omit'))
#different
print('\n\nNISysABP\n', sci.mannwhitneyu(numerical_df['NISysABP_first'], numerical_df['NISysABP_last'], nan_policy='omit'))
#different
print('\n\nNa\n', sci.mannwhitneyu(numerical_df['Na_first'], numerical_df['Na_last'], nan_policy='omit'))
#same
print('\n\nPaCO2\n', sci.mannwhitneyu(numerical_df['PaCO2_first'], numerical_df['PaCO2_last'], nan_policy='omit'))
#different
print('\n\nPaO2\n', sci.mannwhitneyu(numerical_df['PaO2_first'], numerical_df['PaO2_last'], nan_policy='omit'))
#different
print('\n\nPlatelets\n', sci.mannwhitneyu(numerical_df['Platelets_first'], numerical_df['Platelets_last'], nan_policy='omit'))
#different
print('\n\nSysABP\n', sci.mannwhitneyu(numerical_df['SysABP_first'], numerical_df['SysABP_last'], nan_policy='omit'))
#same
print('\n\nTemp\n', sci.mannwhitneyu(numerical_df['Temp_first'], numerical_df['Temp_last'], nan_policy='omit'))
#different
print('\n\nWBC\n', sci.mannwhitneyu(numerical_df['WBC_first'], numerical_df['WBC_last'], nan_policy='omit'))
#different
print('\n\npH\n', sci.mannwhitneyu(numerical_df['pH_first'], numerical_df['pH_last'], nan_policy='omit'))
#different
print('\n\nWeight\n', sci.mannwhitneyu(numerical_df['Weight_first'], numerical_df['Weight_last'], nan_policy='omit'))
#same
# Out:
# BUN
#  MannwhitneyuResult(statistic=17614605.0, pvalue=0.29981721794226535)
#
#
# Creatinine
#  MannwhitneyuResult(statistic=17557180.0, pvalue=0.4663447229665394)
#
#
# DiasABP
#  MannwhitneyuResult(statistic=9006816.5, pvalue=6.947466315455453e-06)
#
#
# FiO2
#  MannwhitneyuResult(statistic=12912728.0, pvalue=0.0)
#
#
# GCS
#  MannwhitneyuResult(statistic=12970276.0, pvalue=4.004574406370745e-140)
#
#
# Glucose
#  MannwhitneyuResult(statistic=19876694.5, pvalue=1.883051148172236e-53)
#
#
# HCO3
#  MannwhitneyuResult(statistic=14709169.0, pvalue=4.7381289527075e-46)
#
#
# HCT
#  MannwhitneyuResult(statistic=19566419.0, pvalue=3.558726270824122e-31)
#
#
# HR
#  MannwhitneyuResult(statistic=19187529.5, pvalue=2.0600174229886776e-22)
#
#
# K
#  MannwhitneyuResult(statistic=18566664.0, pvalue=4.796755746113763e-14)
#
#
# Lactate
#  MannwhitneyuResult(statistic=6451329.5, pvalue=2.2607849065244323e-52)
#
#
# MAP
#  MannwhitneyuResult(statistic=8896929.5, pvalue=0.005540051838291592)
#
#
# Mg
#  MannwhitneyuResult(statistic=13532952.0, pvalue=4.08955520274117e-86)
#
#
# NIDiasABP
#  MannwhitneyuResult(statistic=14962498.5, pvalue=8.955321261570306e-16)
#
#
# NIMAP
#  MannwhitneyuResult(statistic=14760132.5, pvalue=1.6795958166420347e-11)
#
#
# NISysABP
#  MannwhitneyuResult(statistic=14275745.0, pvalue=0.0005352402330792935)
#
#
# Na
#  MannwhitneyuResult(statistic=17335528.5, pvalue=0.9434850748661205)
#
#
# PaCO2
#  MannwhitneyuResult(statistic=10708423.5, pvalue=1.7878334446974753e-06)
#
#
# PaO2
#  MannwhitneyuResult(statistic=13998235.0, pvalue=4.358870962708746e-218)
#
#
# Platelets
#  MannwhitneyuResult(statistic=19870854.0, pvalue=1.479965468395165e-41)
#
#
# SysABP
#  MannwhitneyuResult(statistic=8575675.0, pvalue=0.6354116535964216)
#
#
# Temp
#  MannwhitneyuResult(statistic=12305599.0, pvalue=2.892439692928371e-166)
#
#
# WBC
#  MannwhitneyuResult(statistic=17789766.5, pvalue=0.0008012400962805928)
#
#
# pH
#  MannwhitneyuResult(statistic=8245264.5, pvalue=2.5538291597120635e-57)
#
#
# Weight
#  MannwhitneyuResult(statistic=8042033.0, pvalue=0.1401790438698725)

# %%
# LOADING DATA

df=pd.read_csv("ICU_Challenge_Dataset.csv", sep=",")
df_description = df.describe()
columns = df.columns
columns
# Out:
# Index(['recordid', 'SAPS-I', 'SOFA', 'In-hospital_death', 'Age', 'Gender',
#        'Height', 'Weight', 'CCU', 'CSRU',
#        ...
#        'Platelets_last', 'TroponinI_last', 'TroponinT_last', 'WBC_last',
#        'Weight_last', 'pH_last', 'MechVentStartTime', 'MechVentDuration',
#        'MechVentLast8Hour', 'UrineOutputSum'],
#       dtype='object', length=121)

# %%
df
# Out:
#       recordid  SAPS-I  SOFA  In-hospital_death   Age  Gender  Height  Weight  \
# 0       132539       6     1                  0  54.0     0.0     NaN     NaN
# 1       132540      16     8                  0  76.0     1.0   175.3    76.0
# 2       132541      21    11                  0  44.0     0.0     NaN    56.7
# 3       132543       7     1                  0  68.0     1.0   180.3    84.6
# 4       132545      17     2                  0  88.0     0.0     NaN     NaN
# ...        ...     ...   ...                ...   ...     ...     ...     ...
# 5995    151939      19     6                  1  52.0     1.0     NaN    80.0
# 5996    151383      13     2                  0  90.0     0.0   157.5    72.0
# 5997    149623      12     9                  0  72.0     0.0     NaN   185.0
# 5998    145366      18    11                  1  52.0     1.0   182.9    95.9
# 5999    146804      19     9                  0  55.0     1.0   177.8    81.7
#
#       CCU  CSRU  ...  Platelets_last  TroponinI_last  TroponinT_last  \
# 0       0     0  ...           185.0             NaN             NaN
# 1       0     1  ...           135.0             NaN             NaN
# 2       0     0  ...           113.0             NaN             NaN
# 3       0     0  ...           284.0             NaN             NaN
# 4       0     0  ...            97.0             NaN             NaN
# ...   ...   ...  ...             ...             ...             ...
# 5995    0     0  ...           221.0             NaN             NaN
# 5996    1     0  ...           305.0             NaN             NaN
# 5997    1     0  ...           167.0             NaN            0.02
# 5998    0     0  ...            28.0             NaN             NaN
# 5999    0     1  ...           157.0             NaN             NaN
#
#       WBC_last  Weight_last  pH_last  MechVentStartTime  MechVentDuration  \
# 0          9.4          NaN      NaN                NaN               NaN
# 1         13.3         81.6     7.37               71.0             360.0
# 2          6.2         56.7     7.47              617.0            2160.0
# 3          7.9         84.6      NaN                NaN               NaN
# 4          4.8          NaN      NaN                NaN               NaN
# ...        ...          ...      ...                ...               ...
# 5995      11.5          NaN     7.46              238.0            2440.0
# 5996      12.1         68.5      NaN                NaN               NaN
# 5997      12.7          NaN     7.39              188.0            1200.0
# 5998       5.8         96.2     7.36              100.0            2760.0
# 5999      13.3         98.6     7.41              332.0             960.0
#
#       MechVentLast8Hour  UrineOutputSum
# 0                   NaN             NaN
# 1                   0.0             5.0
# 2                   1.0            14.0
# 3                   NaN             NaN
# 4                   NaN             NaN
# ...                 ...             ...
# 5995                1.0            17.0
# 5996                NaN             NaN
# 5997                0.0            10.0
# 5998                1.0            27.0
# 5999                0.0             7.0
#
# [6000 rows x 121 columns]

# %%
# MISSING DATA - da esplorare
# print(df[df.columns[df.isna().any()]])
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})
missing_value_df.sort_values('percent_missing', inplace=True)
print(missing_value_df)
# Out:
#                          column_name  percent_missing
# recordid                    recordid         0.000000
# SAPS-I                        SAPS-I         0.000000
# SOFA                            SOFA         0.000000
# In-hospital_death  In-hospital_death         0.000000
# Age                              Age         0.000000
# ...                              ...              ...
# TroponinT_first      TroponinT_first        77.766667
# Cholesterol_last    Cholesterol_last        92.133333
# Cholesterol_first  Cholesterol_first        92.133333
# TroponinI_last        TroponinI_last        95.250000
# TroponinI_first      TroponinI_first        95.250000
#
# [121 rows x 2 columns]

# %%
print(df['In-hospital_death'].value_counts())
# Out:
# 0    5162
# 1     838
# Name: In-hospital_death, dtype: int64

# %%
df_col_keep = missing_value_df[missing_value_df['percent_missing']<50]
df_col = df_col_keep['column_name']
df=df[df_col]
df
# Out:
#       recordid  SAPS-I  SOFA  In-hospital_death   Age  CCU  CSRU  SICU  \
# 0       132539       6     1                  0  54.0    0     0     1
# 1       132540      16     8                  0  76.0    0     1     0
# 2       132541      21    11                  0  44.0    0     0     0
# 3       132543       7     1                  0  68.0    0     0     0
# 4       132545      17     2                  0  88.0    0     0     0
# ...        ...     ...   ...                ...   ...  ...   ...   ...
# 5995    151939      19     6                  1  52.0    0     0     1
# 5996    151383      13     2                  0  90.0    1     0     0
# 5997    149623      12     9                  0  72.0    1     0     0
# 5998    145366      18    11                  1  52.0    0     0     0
# 5999    146804      19     9                  0  55.0    0     1     0
#
#       Gender  BUN_first  ...  Weight_first  FiO2_last  FiO2_first  \
# 0        0.0       13.0  ...           NaN        NaN         NaN
# 1        1.0       16.0  ...          80.6       0.40         1.0
# 2        0.0        8.0  ...          56.7       0.40         1.0
# 3        1.0       23.0  ...          84.6        NaN         NaN
# 4        0.0       45.0  ...           NaN        NaN         NaN
# ...      ...        ...  ...           ...        ...         ...
# 5995     1.0       11.0  ...           NaN       0.40         0.6
# 5996     0.0       20.0  ...          72.9       1.00         1.0
# 5997     0.0       62.0  ...           NaN       0.35         0.5
# 5998     1.0       16.0  ...          95.9       0.50         1.0
# 5999     1.0       14.0  ...          98.1       0.50         1.0
#
#       MechVentDuration  MechVentStartTime  UrineOutputSum  MechVentLast8Hour  \
# 0                  NaN                NaN             NaN                NaN
# 1                360.0               71.0             5.0                0.0
# 2               2160.0              617.0            14.0                1.0
# 3                  NaN                NaN             NaN                NaN
# 4                  NaN                NaN             NaN                NaN
# ...                ...                ...             ...                ...
# 5995            2440.0              238.0            17.0                1.0
# 5996               NaN                NaN             NaN                NaN
# 5997            1200.0              188.0            10.0                0.0
# 5998            2760.0              100.0            27.0                1.0
# 5999             960.0              332.0             7.0                0.0
#
#       Lactate_first  Lactate_last  Height
# 0               NaN           NaN     NaN
# 1               NaN           NaN   175.3
# 2               1.3           0.9     NaN
# 3               NaN           NaN   180.3
# 4               NaN           NaN     NaN
# ...             ...           ...     ...
# 5995            NaN           NaN     NaN
# 5996            NaN           NaN   157.5
# 5997            1.4           1.4     NaN
# 5998            9.9           8.2   182.9
# 5999            NaN           NaN   177.8
#
# [6000 rows x 95 columns]

# %%
print(np.unique(df.dtypes))

int_var = list(df.columns[df.dtypes == np.int64])
float_var = list(df.columns[df.dtypes == np.float64])

cat_var = []
num_var = []
for cat in list(df.columns):
    if len(df[cat].unique()) <=3: #conta anche i Nan come valori
        cat_var.append(cat)
    else:
        num_var.append(cat)

categorical_df = df[cat_var]
numerical_df = df[num_var]
print("Numeriche: ", numerical_df.shape[1])
# Out:
# [dtype('int64') dtype('float64')]
# Numeriche:  89

# %%
# Dividing numerical variables that have a matched pair first/last
col_first = []
col_last = []
col_single = []
for x in list(numerical_df.columns):
    if 'first' in x:
        col_first.append(x)
    elif 'last' in x:
        col_last.append(x)
    else:
        col_single.append(x)
col_first.sort()
col_last.sort()
print(col_first)
print(col_last)

df_first_last = pd.concat([df[col_first], df[col_last]], axis=1)
df_numerical_single = df[col_single]
print("Numeriche f/l: ", df_first_last.shape[1])
print("\n\n", col_first)
# Out:
# ['BUN_first', 'Creatinine_first', 'DiasABP_first', 'FiO2_first', 'GCS_first', 'Glucose_first', 'HCO3_first', 'HCT_first', 'HR_first', 'K_first', 'Lactate_first', 'MAP_first', 'Mg_first', 'NIDiasABP_first', 'NIMAP_first', 'NISysABP_first', 'Na_first', 'PaCO2_first', 'PaO2_first', 'Platelets_first', 'SysABP_first', 'Temp_first', 'WBC_first', 'Weight_first', 'pH_first']
# ['BUN_last', 'Creatinine_last', 'DiasABP_last', 'FiO2_last', 'GCS_last', 'Glucose_last', 'HCO3_last', 'HCT_last', 'HR_last', 'K_last', 'Lactate_last', 'MAP_last', 'Mg_last', 'NIDiasABP_last', 'NIMAP_last', 'NISysABP_last', 'Na_last', 'PaCO2_last', 'PaO2_last', 'Platelets_last', 'SysABP_last', 'Temp_last', 'WBC_last', 'Weight_last', 'pH_last']
# Numeriche f/l:  50
#
#
#  ['BUN_first', 'Creatinine_first', 'DiasABP_first', 'FiO2_first', 'GCS_first', 'Glucose_first', 'HCO3_first', 'HCT_first', 'HR_first', 'K_first', 'Lactate_first', 'MAP_first', 'Mg_first', 'NIDiasABP_first', 'NIMAP_first', 'NISysABP_first', 'Na_first', 'PaCO2_first', 'PaO2_first', 'Platelets_first', 'SysABP_first', 'Temp_first', 'WBC_first', 'Weight_first', 'pH_first']

# %%
#Normality test
#Hp0: normal distribution (p-value<0.05 => reject it)
import scipy.stats as sci
for x in list(numerical_df.columns):
    y=sci.normaltest(numerical_df[x], nan_policy='omit')
    print(x, '\n', y, '\n')
# Out:
# recordid
#  NormaltestResult(statistic=842.8952779362795, pvalue=9.281453324358711e-184)
#
# SAPS-I
#  NormaltestResult(statistic=178.46362453579428, pvalue=1.7665109011997907e-39)
#
# SOFA
#  NormaltestResult(statistic=145.41575069788357, pvalue=2.650763275105637e-32)
#
# Age
#  NormaltestResult(statistic=359.68535645125036, pvalue=7.858094294744039e-79)
#
# BUN_first
#  NormaltestResult(statistic=3229.820965379643, pvalue=0.0)
#
# Creatinine_last
#  NormaltestResult(statistic=4722.975745445371, pvalue=0.0)
#
# BUN_last
#  NormaltestResult(statistic=2725.806709376353, pvalue=0.0)
#
# Creatinine_first
#  NormaltestResult(statistic=5735.2033386169605, pvalue=0.0)
#
# HCT_first
#  NormaltestResult(statistic=44.06438668636649, pvalue=2.701095919471259e-10)
#
# HCT_last
#  NormaltestResult(statistic=375.8779347073141, pvalue=2.3941069297250362e-82)
#
# HR_first
#  NormaltestResult(statistic=296.5261930061873, pvalue=4.075259972210311e-65)
#
# HR_median
#  NormaltestResult(statistic=65.8838788512379, pvalue=4.937390581593365e-15)
#
# HR_highest
#  NormaltestResult(statistic=466.340750540311, pvalue=5.43741745297317e-102)
#
# HR_lowest
#  NormaltestResult(statistic=50.39063024228096, pvalue=1.1423881067535228e-11)
#
# HR_last
#  NormaltestResult(statistic=287.39128255812864, pvalue=3.9244239634542613e-63)
#
# Temp_median
#  NormaltestResult(statistic=112.54494272790802, pvalue=3.640627150485427e-25)
#
# Temp_highest
#  NormaltestResult(statistic=358.5854670627672, pvalue=1.3619312403820618e-78)
#
# GCS_highest
#  NormaltestResult(statistic=1884.9478650222618, pvalue=0.0)
#
# Temp_lowest
#  NormaltestResult(statistic=2224.9235620866284, pvalue=0.0)
#
# GCS_lowest
#  NormaltestResult(statistic=31006.958144596, pvalue=0.0)
#
# Temp_last
#  NormaltestResult(statistic=117.35041720710552, pvalue=3.29367451135906e-26)
#
# GCS_median
#  NormaltestResult(statistic=653.7684823196802, pvalue=1.0863701977321717e-142)
#
# Temp_first
#  NormaltestResult(statistic=237.17787370242903, pvalue=3.1439751936514694e-52)
#
# GCS_first
#  NormaltestResult(statistic=36125.28282561526, pvalue=0.0)
#
# GCS_last
#  NormaltestResult(statistic=928.2581633422802, pvalue=2.6996094479956317e-202)
#
# Platelets_last
#  NormaltestResult(statistic=2130.727732813666, pvalue=0.0)
#
# Platelets_first
#  NormaltestResult(statistic=1997.9682428657854, pvalue=0.0)
#
# HCO3_first
#  NormaltestResult(statistic=360.9959829410469, pvalue=4.080546297937946e-79)
#
# HCO3_last
#  NormaltestResult(statistic=317.88978262012245, pvalue=9.356443024573844e-70)
#
# Na_first
#  NormaltestResult(statistic=801.5520402344063, pvalue=8.814262575924323e-175)
#
# Na_last
#  NormaltestResult(statistic=200.41230706475795, pvalue=3.0270560887696285e-44)
#
# K_first
#  NormaltestResult(statistic=3919.0523079379195, pvalue=0.0)
#
# K_last
#  NormaltestResult(statistic=551.183291350887, pvalue=2.051488205841158e-120)
#
# WBC_first
#  NormaltestResult(statistic=7694.945693228238, pvalue=0.0)
#
# WBC_last
#  NormaltestResult(statistic=6347.14777306991, pvalue=0.0)
#
# Mg_last
#  NormaltestResult(statistic=1163.2734355437924, pvalue=2.5025513603108224e-253)
#
# Mg_first
#  NormaltestResult(statistic=3677.9850615668693, pvalue=0.0)
#
# Glucose_lowest
#  NormaltestResult(statistic=1016.5782229200997, pvalue=1.7899614649038293e-221)
#
# Glucose_last
#  NormaltestResult(statistic=3035.9634293168597, pvalue=0.0)
#
# Glucose_median
#  NormaltestResult(statistic=2275.055247974339, pvalue=0.0)
#
# Glucose_first
#  NormaltestResult(statistic=5296.431575142095, pvalue=0.0)
#
# Glucose_highest
#  NormaltestResult(statistic=5260.140435210836, pvalue=0.0)
#
# Weight
#  NormaltestResult(statistic=2033.456414309274, pvalue=0.0)
#
# NISysABP_median
#  NormaltestResult(statistic=326.5474651846614, pvalue=1.2334424625872986e-71)
#
# NISysABP_highest
#  NormaltestResult(statistic=250.659532721952, pvalue=3.715130307867328e-55)
#
# NISysABP_first
#  NormaltestResult(statistic=226.06101948769145, pvalue=8.155927029771724e-50)
#
# NISysABP_last
#  NormaltestResult(statistic=233.39146798779382, pvalue=2.087789287123493e-51)
#
# NISysABP_lowest
#  NormaltestResult(statistic=493.1236478195935, pvalue=8.30922325650129e-108)
#
# NIDiasABP_lowest
#  NormaltestResult(statistic=456.6258267032009, pvalue=6.997800936733961e-100)
#
# NIMAP_lowest
#  NormaltestResult(statistic=554.1933114807125, pvalue=4.554612755879555e-121)
#
# NIMAP_median
#  NormaltestResult(statistic=400.57881888896134, pvalue=1.036131064531712e-87)
#
# NIDiasABP_median
#  NormaltestResult(statistic=363.60265726475757, pvalue=1.1083735983862036e-79)
#
# NIMAP_first
#  NormaltestResult(statistic=238.96789816190676, pvalue=1.2846364432000021e-52)
#
# NIMAP_last
#  NormaltestResult(statistic=500.3028470173526, pvalue=2.2941252763920424e-109)
#
# NIDiasABP_first
#  NormaltestResult(statistic=399.9255633238284, pvalue=1.4363733481296615e-87)
#
# NIMAP_highest
#  NormaltestResult(statistic=461.07884319122377, pvalue=7.550945572327097e-101)
#
# NIDiasABP_highest
#  NormaltestResult(statistic=406.4087099702771, pvalue=5.61655390311247e-89)
#
# NIDiasABP_last
#  NormaltestResult(statistic=564.2436437896049, pvalue=2.9926058915313917e-123)
#
# pH_last
#  NormaltestResult(statistic=592.2569335352633, pvalue=2.4719572075901567e-129)
#
# pH_first
#  NormaltestResult(statistic=590.1213082889625, pvalue=7.190946841665967e-129)
#
# PaCO2_first
#  NormaltestResult(statistic=1324.3567398408802, pvalue=2.6277733742653105e-288)
#
# PaCO2_last
#  NormaltestResult(statistic=1398.9263825632786, pvalue=1.6865364507707866e-304)
#
# PaO2_last
#  NormaltestResult(statistic=2606.0113547435103, pvalue=0.0)
#
# PaO2_first
#  NormaltestResult(statistic=722.0152995486434, pvalue=1.645772412597637e-157)
#
# MAP_first
#  NormaltestResult(statistic=2483.9495509524554, pvalue=0.0)
#
# MAP_lowest
#  NormaltestResult(statistic=2242.4251201066836, pvalue=0.0)
#
# MAP_highest
#  NormaltestResult(statistic=1940.4972201276457, pvalue=0.0)
#
# MAP_last
#  NormaltestResult(statistic=2677.671702297344, pvalue=0.0)
#
# MAP_median
#  NormaltestResult(statistic=3323.780609294391, pvalue=0.0)
#
# SysABP_median
#  NormaltestResult(statistic=260.5226697715747, pvalue=2.680532355405817e-57)
#
# SysABP_last
#  NormaltestResult(statistic=162.24009361453716, pvalue=5.8885897662595145e-36)
#
# SysABP_first
#  NormaltestResult(statistic=301.35824673410826, pvalue=3.6382135221481935e-66)
#
# SysABP_highest
#  NormaltestResult(statistic=389.04107170916507, pvalue=3.317452104560266e-85)
#
# SysABP_lowest
#  NormaltestResult(statistic=319.0461692078054, pvalue=5.248130435616008e-70)
#
# DiasABP_last
#  NormaltestResult(statistic=797.997940216408, pvalue=5.211335061567627e-174)
#
# DiasABP_lowest
#  NormaltestResult(statistic=324.63087222574825, pvalue=3.2158943187870773e-71)
#
# DiasABP_first
#  NormaltestResult(statistic=243.7283291767988, pvalue=1.1886822496089568e-53)
#
# DiasABP_highest
#  NormaltestResult(statistic=1237.2099988455648, pvalue=2.204257224729821e-269)
#
# DiasABP_median
#  NormaltestResult(statistic=290.8543933808881, pvalue=6.946578673504312e-64)
#
# Weight_last
#  NormaltestResult(statistic=1455.000542529976, pvalue=0.0)
#
# Weight_first
#  NormaltestResult(statistic=1528.0243381848263, pvalue=0.0)
#
# FiO2_last
#  NormaltestResult(statistic=1339.8368961165393, pvalue=1.143180171784215e-291)
#
# FiO2_first
#  NormaltestResult(statistic=20963.26590848049, pvalue=0.0)
#
# MechVentDuration
#  NormaltestResult(statistic=1143.2245775391389, pvalue=5.648552885814625e-249)
#
# MechVentStartTime
#  NormaltestResult(statistic=2413.4915952880306, pvalue=0.0)
#
# UrineOutputSum
#  NormaltestResult(statistic=45.51686259276556, pvalue=1.3065886197375528e-10)
#
# Lactate_first
#  NormaltestResult(statistic=2069.1960995059785, pvalue=0.0)
#
# Lactate_last
#  NormaltestResult(statistic=3334.1792186717003, pvalue=0.0)
#
# Height
#  NormaltestResult(statistic=9799.965419713664, pvalue=0.0)

# %%
numerical_df = numerical_df.drop(['BUN_first', 'Creatinine_first', 'Na_first', 'SysABP_first', 'Weight_first'], axis=1)
numerical_df
# Out:
#       recordid  SAPS-I  SOFA   Age  Creatinine_last  BUN_last  HCT_first  \
# 0       132539       6     1  54.0              0.7       8.0       33.7
# 1       132540      16     8  76.0              1.3      21.0       24.7
# 2       132541      21    11  44.0              0.3       3.0       28.5
# 3       132543       7     1  68.0              0.7      10.0       41.3
# 4       132545      17     2  88.0              1.0      25.0       22.6
# ...        ...     ...   ...   ...              ...       ...        ...
# 5995    151939      19     6  52.0              0.6       9.0       30.3
# 5996    151383      13     2  90.0              0.7      23.0       26.0
# 5997    149623      12     9  72.0              2.8      67.0       34.9
# 5998    145366      18    11  52.0              1.0      25.0       18.0
# 5999    146804      19     9  55.0              1.3      23.0       20.0
#
#       HCT_last  HR_first  HR_median  ...  DiasABP_median  Weight_last  \
# 0         30.3      73.0       73.0  ...             NaN          NaN
# 1         29.4      88.0       80.0  ...            59.0         81.6
# 2         29.4     100.0       85.5  ...            67.0         56.7
# 3         36.3      79.0       74.0  ...             NaN         84.6
# 4         30.9      93.0       73.0  ...             NaN          NaN
# ...        ...       ...        ...  ...             ...          ...
# 5995      26.8      68.0      101.0  ...            55.0          NaN
# 5996      32.0      88.0      108.0  ...            89.5         68.5
# 5997      32.0     103.0      100.0  ...            56.0          NaN
# 5998      24.7     143.0      108.0  ...            49.0         96.2
# 5999      28.9      95.0       80.0  ...            54.0         98.6
#
#       FiO2_last  FiO2_first  MechVentDuration  MechVentStartTime  \
# 0           NaN         NaN               NaN                NaN
# 1          0.40         1.0             360.0               71.0
# 2          0.40         1.0            2160.0              617.0
# 3           NaN         NaN               NaN                NaN
# 4           NaN         NaN               NaN                NaN
# ...         ...         ...               ...                ...
# 5995       0.40         0.6            2440.0              238.0
# 5996       1.00         1.0               NaN                NaN
# 5997       0.35         0.5            1200.0              188.0
# 5998       0.50         1.0            2760.0              100.0
# 5999       0.50         1.0             960.0              332.0
#
#       UrineOutputSum  Lactate_first  Lactate_last  Height
# 0                NaN            NaN           NaN     NaN
# 1                5.0            NaN           NaN   175.3
# 2               14.0            1.3           0.9     NaN
# 3                NaN            NaN           NaN   180.3
# 4                NaN            NaN           NaN     NaN
# ...              ...            ...           ...     ...
# 5995            17.0            NaN           NaN     NaN
# 5996             NaN            NaN           NaN   157.5
# 5997            10.0            1.4           1.4     NaN
# 5998            27.0            9.9           8.2   182.9
# 5999             7.0            NaN           NaN   177.8
#
# [6000 rows x 84 columns]

# %%
numerical_df['DiasABP_diff'] = numerical_df['DiasABP_first'] - numerical_df['DiasABP_last']
numerical_df['FiO2_diff'] = numerical_df['FiO2_first'] - numerical_df['FiO2_last']
numerical_df['GCS_diff'] = numerical_df['GCS_first'] - numerical_df['GCS_last']
numerical_df['Glucose_diff'] = numerical_df['Glucose_first'] - numerical_df['Glucose_last']
numerical_df['HCO3_diff'] = numerical_df['HCO3_first'] - numerical_df['HCO3_last']
numerical_df['HCT_diff'] = numerical_df['HCT_first'] - numerical_df['HCT_last']
numerical_df['HR_diff'] = numerical_df['HR_first'] - numerical_df['HR_last']
numerical_df['K_diff'] = numerical_df['K_first'] - numerical_df['K_last']
numerical_df['Lactate_diff'] = numerical_df['Lactate_first'] - numerical_df['Lactate_last']
numerical_df['MAP_diff'] = numerical_df['MAP_first'] - numerical_df['MAP_last']
numerical_df['Mg_diff'] = numerical_df['Mg_first'] - numerical_df['Mg_last']
numerical_df['NIDiasABP_diff'] = numerical_df['NIDiasABP_first'] - numerical_df['NIDiasABP_last']
numerical_df['NIMAP_diff'] = numerical_df['NIMAP_first'] - numerical_df['NIMAP_last']
numerical_df['NISysABP_diff'] = numerical_df['NISysABP_first'] - numerical_df['NISysABP_last']
numerical_df['PaO2_diff'] = numerical_df['PaO2_first'] - numerical_df['PaO2_last']
numerical_df['PaCO2_diff'] = numerical_df['PaCO2_first'] - numerical_df['PaCO2_last']
numerical_df['Temp_diff'] = numerical_df['Temp_first'] - numerical_df['Temp_last']
numerical_df['Platelets_diff'] = numerical_df['Platelets_first'] - numerical_df['Platelets_last']
numerical_df['WBC_diff'] = numerical_df['WBC_first'] - numerical_df['WBC_last']
numerical_df['pH_diff'] = numerical_df['pH_first'] - numerical_df['pH_last']

numerical_df = numerical_df.drop(['DiasABP_first','DiasABP_last', 'FiO2_first', 'FiO2_last', 'GCS_first', 'GCS_last', 'Glucose_first', 'Glucose_last', 'HCO3_first', 'HCO3_last', 'HCT_first', 'HCT_last', 'HR_first', 'HR_last', 'K_first', 'K_last', 'Lactate_first', 'Lactate_last', 'MAP_first', 'MAP_last', 'Mg_first', 'Mg_last', 'NIDiasABP_first', 'NIDiasABP_last', 'NIMAP_first', 'NIMAP_last', 'NISysABP_first', 'NISysABP_last', 'PaO2_first', 'PaO2_last', 'PaCO2_first', 'PaCO2_last', 'Temp_first', 'Temp_last', 'Platelets_first', 'Platelets_last', 'WBC_first', 'WBC_last', 'pH_first', 'pH_last'], axis=1)

numerical_df
# Out:
#       recordid  SAPS-I  SOFA   Age  Creatinine_last  BUN_last  HR_median  \
# 0       132539       6     1  54.0              0.7       8.0       73.0
# 1       132540      16     8  76.0              1.3      21.0       80.0
# 2       132541      21    11  44.0              0.3       3.0       85.5
# 3       132543       7     1  68.0              0.7      10.0       74.0
# 4       132545      17     2  88.0              1.0      25.0       73.0
# ...        ...     ...   ...   ...              ...       ...        ...
# 5995    151939      19     6  52.0              0.6       9.0      101.0
# 5996    151383      13     2  90.0              0.7      23.0      108.0
# 5997    149623      12     9  72.0              2.8      67.0      100.0
# 5998    145366      18    11  52.0              1.0      25.0      108.0
# 5999    146804      19     9  55.0              1.3      23.0       80.0
#
#       HR_highest  HR_lowest  Temp_median  ...  Mg_diff  NIDiasABP_diff  \
# 0           86.0       58.0        37.70  ...     -0.4            10.0
# 1           90.0       65.0        37.45  ...      1.2           -11.0
# 2          113.0       57.0        37.85  ...      0.2             0.0
# 3           88.0       57.0        36.40  ...      0.2           -18.0
# 4           94.0       65.0        37.00  ...     -0.1            -1.0
# ...          ...        ...          ...  ...      ...             ...
# 5995       132.0       59.0        36.70  ...     -0.4             NaN
# 5996       124.0       84.0        36.75  ...      0.2             5.0
# 5997       123.0       79.0        37.05  ...      0.1            12.0
# 5998       143.0       68.0        36.90  ...     -0.6            30.0
# 5999        98.0       69.0        37.60  ...      0.6             0.0
#
#       NIMAP_diff  NISysABP_diff  PaO2_diff  PaCO2_diff  Temp_diff  \
# 0          13.00           19.0        NaN         NaN       -2.7
# 1         -19.00          -35.0      204.0       -12.0       -1.9
# 2          -2.70           -8.0     -108.0         0.0        0.6
# 3         -12.00            0.0        NaN         NaN       -0.7
# 4           2.33            9.0        NaN         NaN        1.1
# ...          ...            ...        ...         ...        ...
# 5995         NaN            NaN      249.0         5.0       -1.4
# 5996        9.67           19.0        NaN         NaN       -1.0
# 5997        6.66           -4.0      -43.0        24.0        0.5
# 5998       33.67           41.0        8.0        -9.0        0.8
# 5999        0.00            0.0      299.0        13.0       -0.5
#
#       Platelets_diff  WBC_diff  pH_diff
# 0               36.0       1.8      NaN
# 1               29.0      -5.9     0.08
# 2              -41.0      -2.0     0.04
# 3              107.0       3.6      NaN
# 4               12.0      -1.0      NaN
# ...              ...       ...      ...
# 5995            32.0       3.0    -0.03
# 5996            59.0       0.3      NaN
# 5997           -12.0      -3.1    -0.12
# 5998             2.0      -2.7    -0.06
# 5999            61.0      -0.6    -0.11
#
# [6000 rows x 64 columns]

# %%
def plot_correlation_heatmap(df):
    plt.figure(figsize=(20,20))
    corr = df.corr()
    ax = sns.heatmap(
        corr,
        vmin=-1, vmax=1, center=0,
        cmap=sns.diverging_palette(20, 220, n=200),
        square=True, annot=True
    )
    ax.set_xticklabels(
        ax.get_xticklabels(),
        rotation=45,
        horizontalalignment='right'
    )
    ax.set_yticklabels(
        ax.get_yticklabels(),
        rotation=45,

    );

# %%
to_drop = []

for x in list(numerical_df.columns):
    if 'highest' in x:
        to_drop.append(x)
    if 'median' in x:
        to_drop.append(x)
    if 'lowest' in x:
        to_drop.append(x)
to_drop
# Out:
# ['HR_median',
#  'HR_highest',
#  'HR_lowest',
#  'Temp_median',
#  'Temp_highest',
#  'GCS_highest',
#  'Temp_lowest',
#  'GCS_lowest',
#  'GCS_median',
#  'Glucose_lowest',
#  'Glucose_median',
#  'Glucose_highest',
#  'NISysABP_median',
#  'NISysABP_highest',
#  'NISysABP_lowest',
#  'NIDiasABP_lowest',
#  'NIMAP_lowest',
#  'NIMAP_median',
#  'NIDiasABP_median',
#  'NIMAP_highest',
#  'NIDiasABP_highest',
#  'MAP_lowest',
#  'MAP_highest',
#  'MAP_median',
#  'SysABP_median',
#  'SysABP_highest',
#  'SysABP_lowest',
#  'DiasABP_lowest',
#  'DiasABP_highest',
#  'DiasABP_median']

# %%
numerical_df = numerical_df.drop(to_drop, axis=1)
numerical_df
# Out:
#       recordid  SAPS-I  SOFA   Age  Creatinine_last  BUN_last  Na_last  \
# 0       132539       6     1  54.0              0.7       8.0    136.0
# 1       132540      16     8  76.0              1.3      21.0    135.0
# 2       132541      21    11  44.0              0.3       3.0    138.0
# 3       132543       7     1  68.0              0.7      10.0    137.0
# 4       132545      17     2  88.0              1.0      25.0    139.0
# ...        ...     ...   ...   ...              ...       ...      ...
# 5995    151939      19     6  52.0              0.6       9.0    140.0
# 5996    151383      13     2  90.0              0.7      23.0    129.0
# 5997    149623      12     9  72.0              2.8      67.0    144.0
# 5998    145366      18    11  52.0              1.0      25.0    134.0
# 5999    146804      19     9  55.0              1.3      23.0    136.0
#
#       Weight  SysABP_last  Weight_last  ...  Mg_diff  NIDiasABP_diff  \
# 0        NaN          NaN          NaN  ...     -0.4            10.0
# 1       76.0        103.0         81.6  ...      1.2           -11.0
# 2       56.7        126.0         56.7  ...      0.2             0.0
# 3       84.6          NaN         84.6  ...      0.2           -18.0
# 4        NaN          NaN          NaN  ...     -0.1            -1.0
# ...      ...          ...          ...  ...      ...             ...
# 5995    80.0        111.0          NaN  ...     -0.4             NaN
# 5996    72.0        148.0         68.5  ...      0.2             5.0
# 5997   185.0        121.0          NaN  ...      0.1            12.0
# 5998    95.9         90.0         96.2  ...     -0.6            30.0
# 5999    81.7        113.0         98.6  ...      0.6             0.0
#
#       NIMAP_diff  NISysABP_diff  PaO2_diff  PaCO2_diff  Temp_diff  \
# 0          13.00           19.0        NaN         NaN       -2.7
# 1         -19.00          -35.0      204.0       -12.0       -1.9
# 2          -2.70           -8.0     -108.0         0.0        0.6
# 3         -12.00            0.0        NaN         NaN       -0.7
# 4           2.33            9.0        NaN         NaN        1.1
# ...          ...            ...        ...         ...        ...
# 5995         NaN            NaN      249.0         5.0       -1.4
# 5996        9.67           19.0        NaN         NaN       -1.0
# 5997        6.66           -4.0      -43.0        24.0        0.5
# 5998       33.67           41.0        8.0        -9.0        0.8
# 5999        0.00            0.0      299.0        13.0       -0.5
#
#       Platelets_diff  WBC_diff  pH_diff
# 0               36.0       1.8      NaN
# 1               29.0      -5.9     0.08
# 2              -41.0      -2.0     0.04
# 3              107.0       3.6      NaN
# 4               12.0      -1.0      NaN
# ...              ...       ...      ...
# 5995            32.0       3.0    -0.03
# 5996            59.0       0.3      NaN
# 5997           -12.0      -3.1    -0.12
# 5998             2.0      -2.7    -0.06
# 5999            61.0      -0.6    -0.11
#
# [6000 rows x 34 columns]

# %%
plot_correlation_heatmap(numerical_df)

# %%
def scremare_highly_correlated(df, threshold):
    corr = df.corr()
    df_after_corr = df.copy()
    cols = list(corr.columns)
    for c, col in enumerate(corr.columns):
        pos=list(np.where(corr[col]>threshold)[0])
        pos_uno = list(np.where(corr[col]==1)[0])
        pos.remove(pos_uno[0])
        #print(col + '')
        if len(pos)>0:
            for el in pos:
                #print(el)
                cols[el] = 0


    print('Before removing highly correlated columns: ' + str(len(df.columns)))
    cols_to_keep=[]
    for col in cols:
        if col!=0:
            cols_to_keep.append(col)

    print('After removing highly correlated columns: ' + str(len(cols_to_keep)))

    return df_after_corr[cols_to_keep]

# %%
numerical_df = scremare_highly_correlated(numerical_df, 0.8)
numerical_df
# Out:
# Before removing highly correlated columns: 34
# After removing highly correlated columns: 27
#       recordid  SAPS-I  SOFA   Age  Creatinine_last  BUN_last  Na_last  \
# 0       132539       6     1  54.0              0.7       8.0    136.0
# 1       132540      16     8  76.0              1.3      21.0    135.0
# 2       132541      21    11  44.0              0.3       3.0    138.0
# 3       132543       7     1  68.0              0.7      10.0    137.0
# 4       132545      17     2  88.0              1.0      25.0    139.0
# ...        ...     ...   ...   ...              ...       ...      ...
# 5995    151939      19     6  52.0              0.6       9.0    140.0
# 5996    151383      13     2  90.0              0.7      23.0    129.0
# 5997    149623      12     9  72.0              2.8      67.0    144.0
# 5998    145366      18    11  52.0              1.0      25.0    134.0
# 5999    146804      19     9  55.0              1.3      23.0    136.0
#
#       SysABP_last  MechVentStartTime  Height  ...  K_diff  Lactate_diff  \
# 0             NaN                NaN     NaN  ...     0.4           NaN
# 1           103.0               71.0   175.3  ...     0.8           NaN
# 2           126.0              617.0     NaN  ...    -0.4           0.4
# 3             NaN                NaN   180.3  ...     0.2           NaN
# 4             NaN                NaN     NaN  ...     1.9           NaN
# ...           ...                ...     ...  ...     ...           ...
# 5995        111.0              238.0     NaN  ...     0.7           NaN
# 5996        148.0                NaN   157.5  ...    -0.9           NaN
# 5997        121.0              188.0     NaN  ...     0.6           0.0
# 5998         90.0              100.0   182.9  ...    -0.9           1.7
# 5999        113.0              332.0   177.8  ...     0.8           NaN
#
#       MAP_diff  Mg_diff  PaO2_diff  PaCO2_diff  Temp_diff  Platelets_diff  \
# 0          NaN     -0.4        NaN         NaN       -2.7            36.0
# 1         10.0      1.2      204.0       -12.0       -1.9            29.0
# 2         15.0      0.2     -108.0         0.0        0.6           -41.0
# 3          NaN      0.2        NaN         NaN       -0.7           107.0
# 4          NaN     -0.1        NaN         NaN        1.1            12.0
# ...        ...      ...        ...         ...        ...             ...
# 5995      12.0     -0.4      249.0         5.0       -1.4            32.0
# 5996       3.0      0.2        NaN         NaN       -1.0            59.0
# 5997      35.0      0.1      -43.0        24.0        0.5           -12.0
# 5998     -14.0     -0.6        8.0        -9.0        0.8             2.0
# 5999       5.0      0.6      299.0        13.0       -0.5            61.0
#
#       WBC_diff  pH_diff
# 0          1.8      NaN
# 1         -5.9     0.08
# 2         -2.0     0.04
# 3          3.6      NaN
# 4         -1.0      NaN
# ...        ...      ...
# 5995       3.0    -0.03
# 5996       0.3      NaN
# 5997      -3.1    -0.12
# 5998      -2.7    -0.06
# 5999      -0.6    -0.11
#
# [6000 rows x 27 columns]

# %%
mean_values=numerical_df.mean()
mean_values
# Out:
# recordid             140965.097167
# SAPS-I                   14.170333
# SOFA                      6.345500
# Age                      64.568500
# Creatinine_last           1.358106
# BUN_last                 25.456378
# Na_last                 138.878016
# SysABP_last             122.858804
# MechVentStartTime       288.830395
# Height                  174.775374
# DiasABP_diff              1.073643
# FiO2_diff                 0.279240
# GCS_diff                 -2.301052
# Glucose_diff             20.407496
# HCO3_diff                -1.078138
# HCT_diff                  1.116401
# HR_diff                   3.770595
# K_diff                    0.113969
# Lactate_diff              0.647751
# MAP_diff                  1.992523
# Mg_diff                  -0.109279
# PaO2_diff                86.523344
# PaCO2_diff                1.379640
# Temp_diff                -0.454552
# Platelets_diff           23.628346
# WBC_diff                  0.609017
# pH_diff                  -0.029230
# dtype: float64

# %%
numerical_df = numerical_df.fillna(value=mean_values)
numerical_df.isnull().sum()
# Out:
# recordid             0
# SAPS-I               0
# SOFA                 0
# Age                  0
# Creatinine_last      0
# BUN_last             0
# Na_last              0
# SysABP_last          0
# MechVentStartTime    0
# Height               0
# DiasABP_diff         0
# FiO2_diff            0
# GCS_diff             0
# Glucose_diff         0
# HCO3_diff            0
# HCT_diff             0
# HR_diff              0
# K_diff               0
# Lactate_diff         0
# MAP_diff             0
# Mg_diff              0
# PaO2_diff            0
# PaCO2_diff           0
# Temp_diff            0
# Platelets_diff       0
# WBC_diff             0
# pH_diff              0
# dtype: int64

# %%
numerical_df.hist(figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'recordid'}>,
#         <AxesSubplot:title={'center':'SAPS-I'}>,
#         <AxesSubplot:title={'center':'SOFA'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Creatinine_last'}>],
#        [<AxesSubplot:title={'center':'BUN_last'}>,
#         <AxesSubplot:title={'center':'Na_last'}>,
#         <AxesSubplot:title={'center':'SysABP_last'}>,
#         <AxesSubplot:title={'center':'MechVentStartTime'}>,
#         <AxesSubplot:title={'center':'Height'}>],
#        [<AxesSubplot:title={'center':'DiasABP_diff'}>,
#         <AxesSubplot:title={'center':'FiO2_diff'}>,
#         <AxesSubplot:title={'center':'GCS_diff'}>,
#         <AxesSubplot:title={'center':'Glucose_diff'}>,
#         <AxesSubplot:title={'center':'HCO3_diff'}>],
#        [<AxesSubplot:title={'center':'HCT_diff'}>,
#         <AxesSubplot:title={'center':'HR_diff'}>,
#         <AxesSubplot:title={'center':'K_diff'}>,
#         <AxesSubplot:title={'center':'Lactate_diff'}>,
#         <AxesSubplot:title={'center':'MAP_diff'}>],
#        [<AxesSubplot:title={'center':'Mg_diff'}>,
#         <AxesSubplot:title={'center':'PaO2_diff'}>,
#         <AxesSubplot:title={'center':'PaCO2_diff'}>,
#         <AxesSubplot:title={'center':'Temp_diff'}>,
#         <AxesSubplot:title={'center':'Platelets_diff'}>],
#        [<AxesSubplot:title={'center':'WBC_diff'}>,
#         <AxesSubplot:title={'center':'pH_diff'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
import matplotlib.pyplot as plt
crea_log= np.log(numerical_df['Creatinine_last'])
sns.distplot(crea_log)
fig = plt.figure()
crea_log.hist()
# Out:
# C:\Users\Alice Donati\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:>

# %%
import seaborn as sns
sns.boxplot(x=categorical_df['In-hospital_death'], y=crea_log)
plt.show()

# %%
sns.boxplot(x=categorical_df['In-hospital_death'], y=numerical_df['Creatinine_last'])
# Out:
# <AxesSubplot:xlabel='In-hospital_death', ylabel='Creatinine_last'>

# %%
import matplotlib.pyplot as plt
BUN_log= np.log(numerical_df['BUN_last'])
sns.distplot(crea_log)
fig = plt.figure()
BUN_log.hist()
# Out:
# C:\Users\Alice Donati\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:>

# %%
import seaborn as sns
sns.boxplot(x=categorical_df['In-hospital_death'], y=BUN_log)
plt.show()

# %%
sns.boxplot(x=categorical_df['In-hospital_death'], y=numerical_df['BUN_last'])
# Out:
# <AxesSubplot:xlabel='In-hospital_death', ylabel='BUN_last'>

# %%
numerical_df=numerical_df.drop(['Creatinine_last', 'BUN_last'], axis=1)
numerical_df.insert(2, 'Creatinine_last_log', crea_log)
numerical_df.insert(3, 'BUN_last_log', BUN_log)
numerical_df
# Out:
#       recordid  SAPS-I  Creatinine_last_log  BUN_last_log  SOFA   Age  \
# 0       132539       6            -0.356675      2.079442     1  54.0
# 1       132540      16             0.262364      3.044522     8  76.0
# 2       132541      21            -1.203973      1.098612    11  44.0
# 3       132543       7            -0.356675      2.302585     1  68.0
# 4       132545      17             0.000000      3.218876     2  88.0
# ...        ...     ...                  ...           ...   ...   ...
# 5995    151939      19            -0.510826      2.197225     6  52.0
# 5996    151383      13            -0.356675      3.135494     2  90.0
# 5997    149623      12             1.029619      4.204693     9  72.0
# 5998    145366      18             0.000000      3.218876    11  52.0
# 5999    146804      19             0.262364      3.135494     9  55.0
#
#       Na_last  SysABP_last  MechVentStartTime      Height  ...  K_diff  \
# 0       136.0   122.858804         288.830395  174.775374  ...     0.4
# 1       135.0   103.000000          71.000000  175.300000  ...     0.8
# 2       138.0   126.000000         617.000000  174.775374  ...    -0.4
# 3       137.0   122.858804         288.830395  180.300000  ...     0.2
# 4       139.0   122.858804         288.830395  174.775374  ...     1.9
# ...       ...          ...                ...         ...  ...     ...
# 5995    140.0   111.000000         238.000000  174.775374  ...     0.7
# 5996    129.0   148.000000         288.830395  157.500000  ...    -0.9
# 5997    144.0   121.000000         188.000000  174.775374  ...     0.6
# 5998    134.0    90.000000         100.000000  182.900000  ...    -0.9
# 5999    136.0   113.000000         332.000000  177.800000  ...     0.8
#
#       Lactate_diff   MAP_diff  Mg_diff   PaO2_diff  PaCO2_diff  Temp_diff  \
# 0         0.647751   1.992523     -0.4   86.523344     1.37964       -2.7
# 1         0.647751  10.000000      1.2  204.000000   -12.00000       -1.9
# 2         0.400000  15.000000      0.2 -108.000000     0.00000        0.6
# 3         0.647751   1.992523      0.2   86.523344     1.37964       -0.7
# 4         0.647751   1.992523     -0.1   86.523344     1.37964        1.1
# ...            ...        ...      ...         ...         ...        ...
# 5995      0.647751  12.000000     -0.4  249.000000     5.00000       -1.4
# 5996      0.647751   3.000000      0.2   86.523344     1.37964       -1.0
# 5997      0.000000  35.000000      0.1  -43.000000    24.00000        0.5
# 5998      1.700000 -14.000000     -0.6    8.000000    -9.00000        0.8
# 5999      0.647751   5.000000      0.6  299.000000    13.00000       -0.5
#
#       Platelets_diff  WBC_diff  pH_diff
# 0               36.0       1.8 -0.02923
# 1               29.0      -5.9  0.08000
# 2              -41.0      -2.0  0.04000
# 3              107.0       3.6 -0.02923
# 4               12.0      -1.0 -0.02923
# ...              ...       ...      ...
# 5995            32.0       3.0 -0.03000
# 5996            59.0       0.3 -0.02923
# 5997           -12.0      -3.1 -0.12000
# 5998             2.0      -2.7 -0.06000
# 5999            61.0      -0.6 -0.11000
#
# [6000 rows x 27 columns]

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler().fit(numerical_df)
scaled_df=pd.DataFrame(scaler.transform(numerical_df))
scaled_df.columns = numerical_df.columns

scaled_df

#x = numerical_df.values #returns a numpy array
#s_scaler = StandardScaler()
#x_scaled = s_scaler.fit_transform(x)
#df_scaled = pd.DataFrame(data=x_scaled)
#df_scaled
# Out:
#       recordid    SAPS-I  Creatinine_last_log  BUN_last_log      SOFA  \
# 0    -1.508884 -1.342626            -0.629755     -1.280057 -1.264658
# 1    -1.508705  0.300668             0.333993      0.085820  0.391428
# 2    -1.508526  1.122315            -1.948867     -2.668222  1.101179
# 3    -1.508168 -1.178297            -0.629755     -0.964242 -1.264658
# 4    -1.507810  0.464998            -0.074468      0.332582 -1.028074
# ...        ...       ...                  ...           ...       ...
# 5995  1.965126  0.793656            -0.869744     -1.113358 -0.081740
# 5996  1.865562 -0.192320            -0.629755      0.214572 -1.028074
# 5997  1.550394 -0.356650             1.528490      1.727806  0.628011
# 5998  0.788082  0.629327            -0.074468      0.332582  1.101179
# 5999  1.045588  0.793656             0.333993      0.214572  0.628011
#
#            Age   Na_last   SysABP_last  MechVentStartTime        Height  ...  \
# 0    -0.604645 -0.669431  7.142229e-16           0.000000  1.881342e-16  ...
# 1     0.654019 -0.902033 -9.980830e-01          -0.564428  3.472704e-03  ...
# 2    -1.176765 -0.204228  1.578733e-01           0.850332  1.881342e-16  ...
# 3     0.196323 -0.436830  7.142229e-16           0.000000  3.656963e-02  ...
# 4     1.340564  0.028374  7.142229e-16           0.000000  1.881342e-16  ...
# ...        ...       ...           ...                ...           ...  ...
# 5995 -0.719069  0.260976 -5.960113e-01          -0.131708  1.881342e-16  ...
# 5996  1.454988 -2.297644  1.263571e+00           0.000000 -1.143523e-01  ...
# 5997  0.425171  1.191382 -9.342155e-02          -0.261265  1.881342e-16  ...
# 5998 -0.719069 -1.134635 -1.651450e+00          -0.489285  5.378003e-02  ...
# 5999 -0.547433 -0.669431 -4.954933e-01           0.111858  2.002117e-02  ...
#
#         K_diff  Lactate_diff  MAP_diff   Mg_diff     PaO2_diff    PaCO2_diff  \
# 0     0.379723  7.908244e-17  0.000000 -0.660524  1.318287e-16  2.766267e-17
# 1     0.910746  7.908244e-17  0.328683  2.974703  1.089787e+00 -1.666857e+00
# 2    -0.682324 -1.764760e-01  0.533918  0.702686 -1.804519e+00 -1.718778e-01
# 3     0.114211  7.908244e-17  0.000000  0.702686  1.318287e-16  2.766267e-17
# 4     2.371061  7.908244e-17  0.000000  0.021081  1.318287e-16  2.766267e-17
# ...        ...           ...       ...       ...           ...           ...
# 5995  0.777991  7.908244e-17  0.410777 -0.660524  1.507234e+00  4.510303e-01
# 5996 -1.346103  7.908244e-17  0.041354  0.702686  1.318287e-16  2.766267e-17
# 5997  0.645235 -4.614005e-01  1.354858  0.475485 -1.201539e+00  2.818081e+00
# 5998 -1.346103  7.495288e-01 -0.656445 -1.114927 -7.284314e-01 -1.293112e+00
# 5999  0.910746  7.908244e-17  0.123448  1.611493  1.971066e+00  1.447683e+00
#
#       Temp_diff  Platelets_diff  WBC_diff       pH_diff
# 0     -1.902601        0.222602  0.205010 -8.646334e-17
# 1     -1.224749        0.096652 -1.120432  1.361086e+00
# 2      0.893538       -1.162852 -0.449104  8.626583e-01
# 3     -0.207972        1.500099  0.514854 -8.646334e-17
# 4      1.317195       -0.209228 -0.276969 -8.646334e-17
# ...         ...             ...       ...           ...
# 5995  -0.801092        0.150630  0.411573 -9.589378e-03
# 5996  -0.462166        0.636439 -0.053193 -8.646334e-17
# 5997   0.808806       -0.641058 -0.638453 -1.131051e+00
# 5998   1.063001       -0.389157 -0.569599 -3.834098e-01
# 5999  -0.038509        0.672425 -0.208115 -1.006444e+00
#
# [6000 rows x 27 columns]

# %%
frames=[scaled_df, categorical_df]
df_1 = pd.concat(frames, axis=1)
df_1
# Out:
#       recordid    SAPS-I  Creatinine_last_log  BUN_last_log      SOFA  \
# 0    -1.508884 -1.342626            -0.629755     -1.280057 -1.264658
# 1    -1.508705  0.300668             0.333993      0.085820  0.391428
# 2    -1.508526  1.122315            -1.948867     -2.668222  1.101179
# 3    -1.508168 -1.178297            -0.629755     -0.964242 -1.264658
# 4    -1.507810  0.464998            -0.074468      0.332582 -1.028074
# ...        ...       ...                  ...           ...       ...
# 5995  1.965126  0.793656            -0.869744     -1.113358 -0.081740
# 5996  1.865562 -0.192320            -0.629755      0.214572 -1.028074
# 5997  1.550394 -0.356650             1.528490      1.727806  0.628011
# 5998  0.788082  0.629327            -0.074468      0.332582  1.101179
# 5999  1.045588  0.793656             0.333993      0.214572  0.628011
#
#            Age   Na_last   SysABP_last  MechVentStartTime        Height  ...  \
# 0    -0.604645 -0.669431  7.142229e-16           0.000000  1.881342e-16  ...
# 1     0.654019 -0.902033 -9.980830e-01          -0.564428  3.472704e-03  ...
# 2    -1.176765 -0.204228  1.578733e-01           0.850332  1.881342e-16  ...
# 3     0.196323 -0.436830  7.142229e-16           0.000000  3.656963e-02  ...
# 4     1.340564  0.028374  7.142229e-16           0.000000  1.881342e-16  ...
# ...        ...       ...           ...                ...           ...  ...
# 5995 -0.719069  0.260976 -5.960113e-01          -0.131708  1.881342e-16  ...
# 5996  1.454988 -2.297644  1.263571e+00           0.000000 -1.143523e-01  ...
# 5997  0.425171  1.191382 -9.342155e-02          -0.261265  1.881342e-16  ...
# 5998 -0.719069 -1.134635 -1.651450e+00          -0.489285  5.378003e-02  ...
# 5999 -0.547433 -0.669431 -4.954933e-01           0.111858  2.002117e-02  ...
#
#       Temp_diff  Platelets_diff  WBC_diff       pH_diff  In-hospital_death  \
# 0     -1.902601        0.222602  0.205010 -8.646334e-17                  0
# 1     -1.224749        0.096652 -1.120432  1.361086e+00                  0
# 2      0.893538       -1.162852 -0.449104  8.626583e-01                  0
# 3     -0.207972        1.500099  0.514854 -8.646334e-17                  0
# 4      1.317195       -0.209228 -0.276969 -8.646334e-17                  0
# ...         ...             ...       ...           ...                ...
# 5995  -0.801092        0.150630  0.411573 -9.589378e-03                  1
# 5996  -0.462166        0.636439 -0.053193 -8.646334e-17                  0
# 5997   0.808806       -0.641058 -0.638453 -1.131051e+00                  0
# 5998   1.063001       -0.389157 -0.569599 -3.834098e-01                  1
# 5999  -0.038509        0.672425 -0.208115 -1.006444e+00                  0
#
#       CCU  CSRU  SICU  Gender  MechVentLast8Hour
# 0       0     0     1     0.0                NaN
# 1       0     1     0     1.0                0.0
# 2       0     0     0     0.0                1.0
# 3       0     0     0     1.0                NaN
# 4       0     0     0     0.0                NaN
# ...   ...   ...   ...     ...                ...
# 5995    0     0     1     1.0                1.0
# 5996    1     0     0     0.0                NaN
# 5997    1     0     0     0.0                0.0
# 5998    0     0     0     1.0                1.0
# 5999    0     1     0     1.0                0.0
#
# [6000 rows x 33 columns]

# %%
categorical_df.isnull().sum()
# Out:
# In-hospital_death       0
# CCU                     0
# CSRU                    0
# SICU                    0
# Gender                  6
# MechVentLast8Hour    2256
# dtype: int64

# %%
#tolgo 6 righe con genere nan
indexNames = df_1[df_1['Gender'].isnull()].index
df_1.drop(indexNames , inplace=True)
df_1
# Out:
#       recordid    SAPS-I  Creatinine_last_log  BUN_last_log      SOFA  \
# 0    -1.508884 -1.342626            -0.629755     -1.280057 -1.264658
# 1    -1.508705  0.300668             0.333993      0.085820  0.391428
# 2    -1.508526  1.122315            -1.948867     -2.668222  1.101179
# 3    -1.508168 -1.178297            -0.629755     -0.964242 -1.264658
# 4    -1.507810  0.464998            -0.074468      0.332582 -1.028074
# ...        ...       ...                  ...           ...       ...
# 5995  1.965126  0.793656            -0.869744     -1.113358 -0.081740
# 5996  1.865562 -0.192320            -0.629755      0.214572 -1.028074
# 5997  1.550394 -0.356650             1.528490      1.727806  0.628011
# 5998  0.788082  0.629327            -0.074468      0.332582  1.101179
# 5999  1.045588  0.793656             0.333993      0.214572  0.628011
#
#            Age   Na_last   SysABP_last  MechVentStartTime        Height  ...  \
# 0    -0.604645 -0.669431  7.142229e-16           0.000000  1.881342e-16  ...
# 1     0.654019 -0.902033 -9.980830e-01          -0.564428  3.472704e-03  ...
# 2    -1.176765 -0.204228  1.578733e-01           0.850332  1.881342e-16  ...
# 3     0.196323 -0.436830  7.142229e-16           0.000000  3.656963e-02  ...
# 4     1.340564  0.028374  7.142229e-16           0.000000  1.881342e-16  ...
# ...        ...       ...           ...                ...           ...  ...
# 5995 -0.719069  0.260976 -5.960113e-01          -0.131708  1.881342e-16  ...
# 5996  1.454988 -2.297644  1.263571e+00           0.000000 -1.143523e-01  ...
# 5997  0.425171  1.191382 -9.342155e-02          -0.261265  1.881342e-16  ...
# 5998 -0.719069 -1.134635 -1.651450e+00          -0.489285  5.378003e-02  ...
# 5999 -0.547433 -0.669431 -4.954933e-01           0.111858  2.002117e-02  ...
#
#       Temp_diff  Platelets_diff  WBC_diff       pH_diff  In-hospital_death  \
# 0     -1.902601        0.222602  0.205010 -8.646334e-17                  0
# 1     -1.224749        0.096652 -1.120432  1.361086e+00                  0
# 2      0.893538       -1.162852 -0.449104  8.626583e-01                  0
# 3     -0.207972        1.500099  0.514854 -8.646334e-17                  0
# 4      1.317195       -0.209228 -0.276969 -8.646334e-17                  0
# ...         ...             ...       ...           ...                ...
# 5995  -0.801092        0.150630  0.411573 -9.589378e-03                  1
# 5996  -0.462166        0.636439 -0.053193 -8.646334e-17                  0
# 5997   0.808806       -0.641058 -0.638453 -1.131051e+00                  0
# 5998   1.063001       -0.389157 -0.569599 -3.834098e-01                  1
# 5999  -0.038509        0.672425 -0.208115 -1.006444e+00                  0
#
#       CCU  CSRU  SICU  Gender  MechVentLast8Hour
# 0       0     0     1     0.0                NaN
# 1       0     1     0     1.0                0.0
# 2       0     0     0     0.0                1.0
# 3       0     0     0     1.0                NaN
# 4       0     0     0     0.0                NaN
# ...   ...   ...   ...     ...                ...
# 5995    0     0     1     1.0                1.0
# 5996    1     0     0     0.0                NaN
# 5997    1     0     0     0.0                0.0
# 5998    0     0     0     1.0                1.0
# 5999    0     1     0     1.0                0.0
#
# [5994 rows x 33 columns]

# %%
#tolgo righe con mech nan
indexNames = df_1[df_1['MechVentLast8Hour'].isnull()].index
df_1.drop(indexNames, inplace=True)
df_1
# Out:
#       recordid    SAPS-I  Creatinine_last_log  BUN_last_log      SOFA  \
# 1    -1.508705  0.300668             0.333993      0.085820  0.391428
# 2    -1.508526  1.122315            -1.948867     -2.668222  1.101179
# 5    -1.507451 -0.027991            -0.629755     -0.299047  1.101179
# 7    -1.506735  0.793656            -0.869744      1.523650  0.391428
# 9    -1.506019 -0.027991             0.333993      0.151660 -0.081740
# ...        ...       ...                  ...           ...       ...
# 5994  1.854997  0.300668             0.209379     -0.299047  0.864595
# 5995  1.965126  0.793656            -0.869744     -1.113358 -0.081740
# 5997  1.550394 -0.356650             1.528490      1.727806  0.628011
# 5998  0.788082  0.629327            -0.074468      0.332582  1.101179
# 5999  1.045588  0.793656             0.333993      0.214572  0.628011
#
#            Age   Na_last  SysABP_last  MechVentStartTime        Height  ...  \
# 1     0.654019 -0.902033    -0.998083          -0.564428  3.472704e-03  ...
# 2    -1.176765 -0.204228     0.157873           0.850332  1.881342e-16  ...
# 5    -0.032525 -0.669431    -1.601191           0.010804  3.656963e-02  ...
# 7     0.768443 -0.436830     0.157873           2.075940 -8.059348e-02  ...
# 9     0.539595  0.028374     0.559945          -0.600704  3.472704e-03  ...
# ...        ...       ...          ...                ...           ...  ...
# 5994  0.882867  0.028374     1.816419          -0.271630  2.002117e-02  ...
# 5995 -0.719069  0.260976    -0.596011          -0.131708  1.881342e-16  ...
# 5997  0.425171  1.191382    -0.093422          -0.261265  1.881342e-16  ...
# 5998 -0.719069 -1.134635    -1.651450          -0.489285  5.378003e-02  ...
# 5999 -0.547433 -0.669431    -0.495493           0.111858  2.002117e-02  ...
#
#       Temp_diff  Platelets_diff  WBC_diff   pH_diff  In-hospital_death  CCU  \
# 1     -1.224749        0.096652 -1.120432  1.361086                  0    0
# 2      0.893538       -1.162852 -0.449104  0.862658                  0    0
# 5     -0.885824        1.428128  1.737015 -1.754085                  0    1
# 7      1.571390       -0.623065 -1.378635  0.738051                  1    0
# 9     -1.817870       -0.713030 -0.586812  0.488838                  0    0
# ...         ...             ...       ...       ...                ...  ...
# 5994   0.300417       -0.677044  0.824698 -0.632623                  0    0
# 5995  -0.801092        0.150630  0.411573 -0.009589                  1    0
# 5997   0.808806       -0.641058 -0.638453 -1.131051                  0    1
# 5998   1.063001       -0.389157 -0.569599 -0.383410                  1    0
# 5999  -0.038509        0.672425 -0.208115 -1.006444                  0    0
#
#       CSRU  SICU  Gender  MechVentLast8Hour
# 1        1     0     1.0                0.0
# 2        0     0     0.0                1.0
# 5        0     0     1.0                1.0
# 7        0     0     0.0                1.0
# 9        1     0     1.0                0.0
# ...    ...   ...     ...                ...
# 5994     1     0     1.0                0.0
# 5995     0     1     1.0                1.0
# 5997     0     0     0.0                0.0
# 5998     0     0     1.0                1.0
# 5999     1     0     1.0                0.0
#
# [3741 rows x 33 columns]

# %%
plot_correlation_heatmap(df_1)

# %%
df_1=df_1.drop(['recordid'], axis=1)
df_1
# Out:
#         SAPS-I  Creatinine_last_log  BUN_last_log      SOFA       Age  \
# 1     0.300668             0.333993      0.085820  0.391428  0.654019
# 2     1.122315            -1.948867     -2.668222  1.101179 -1.176765
# 5    -0.027991            -0.629755     -0.299047  1.101179 -0.032525
# 7     0.793656            -0.869744      1.523650  0.391428  0.768443
# 9    -0.027991             0.333993      0.151660 -0.081740  0.539595
# ...        ...                  ...           ...       ...       ...
# 5994  0.300668             0.209379     -0.299047  0.864595  0.882867
# 5995  0.793656            -0.869744     -1.113358 -0.081740 -0.719069
# 5997 -0.356650             1.528490      1.727806  0.628011  0.425171
# 5998  0.629327            -0.074468      0.332582  1.101179 -0.719069
# 5999  0.793656             0.333993      0.214572  0.628011 -0.547433
#
#        Na_last  SysABP_last  MechVentStartTime        Height  DiasABP_diff  \
# 1    -0.902033    -0.998083          -0.564428  3.472704e-03      1.106864
# 2    -0.204228     0.157873           0.850332  1.881342e-16      0.736089
# 5    -0.669431    -1.601191           0.010804  3.656963e-02      0.958554
# 7    -0.436830     0.157873           2.075940 -8.059348e-02      1.032709
# 9     0.028374     0.559945          -0.600704  3.472704e-03     -0.747011
# ...        ...          ...                ...           ...           ...
# 5994  0.028374     1.816419          -0.271630  2.002117e-02     -1.191942
# 5995  0.260976    -0.596011          -0.131708  1.881342e-16      0.661934
# 5997  1.191382    -0.093422          -0.261265  1.881342e-16      0.291159
# 5998 -1.134635    -1.651450          -0.489285  5.378003e-02      0.365314
# 5999 -0.669431    -0.495493           0.111858  2.002117e-02     -0.302081
#
#       ...  Temp_diff  Platelets_diff  WBC_diff   pH_diff  In-hospital_death  \
# 1     ...  -1.224749        0.096652 -1.120432  1.361086                  0
# 2     ...   0.893538       -1.162852 -0.449104  0.862658                  0
# 5     ...  -0.885824        1.428128  1.737015 -1.754085                  0
# 7     ...   1.571390       -0.623065 -1.378635  0.738051                  1
# 9     ...  -1.817870       -0.713030 -0.586812  0.488838                  0
# ...   ...        ...             ...       ...       ...                ...
# 5994  ...   0.300417       -0.677044  0.824698 -0.632623                  0
# 5995  ...  -0.801092        0.150630  0.411573 -0.009589                  1
# 5997  ...   0.808806       -0.641058 -0.638453 -1.131051                  0
# 5998  ...   1.063001       -0.389157 -0.569599 -0.383410                  1
# 5999  ...  -0.038509        0.672425 -0.208115 -1.006444                  0
#
#       CCU  CSRU  SICU  Gender  MechVentLast8Hour
# 1       0     1     0     1.0                0.0
# 2       0     0     0     0.0                1.0
# 5       1     0     0     1.0                1.0
# 7       0     0     0     0.0                1.0
# 9       0     1     0     1.0                0.0
# ...   ...   ...   ...     ...                ...
# 5994    0     1     0     1.0                0.0
# 5995    0     0     1     1.0                1.0
# 5997    1     0     0     0.0                0.0
# 5998    0     0     0     1.0                1.0
# 5999    0     1     0     1.0                0.0
#
# [3741 rows x 32 columns]

# %%
df_1.to_csv('df_1.csv', index=False)
